# %%
import json

with open("rand_circuits_batch_2.json","r") as file:
    data = json.load(file)

total_run_time = sum(job["run_time"] for job in data)
print("total_run_time", total_run_time)
# Out:
# total_run_time 1570.8272000000027

# %%
with open("rand_circuits_batch_1.json","r") as file:
    data = json.load(file)

total_run_time = sum(job["run_time"] for job in data)
print("total_run_time", total_run_time)
# Out:
# total_run_time 1620.4384999999963

# %%
with open("rand_circuits_batch_3.json","r") as file:
    data = json.load(file)

total_run_time = sum(job["run_time"] for job in data)
print("total_run_time", total_run_time)
# Out:
# total_run_time 1567.4147000000014

# %%
with open("rand_circuits_batch_4.json","r") as file:
    data = json.load(file)

total_run_time = sum(job["run_time"] for job in data)
print("total_run_time", total_run_time)
# Out:
# total_run_time 1575.7365000000068
